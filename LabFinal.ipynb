# %%
from google.colab import files
print("Upload spam.csv:")
uploaded = files.upload()
# Out:
# Upload spam.csv:
#      <input type="file" id="files-6503ec58-ac28-41b5-9c83-92de7326ce72" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6503ec58-ac28-41b5-9c83-92de7326ce72">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Ab yeh kaam karega kyunki file upload ho chuki hai
df = pd.read_csv("spam.csv", encoding='latin-1')
df = df[['v1', 'v2']]
df.columns = ['label', 'message']
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

print(f"Total messages: {len(df)}")
print(f"Spam: {df['label'].sum()} | Ham: {len(df)-df['label'].sum()}")

# Rest of the code...
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['message'])
X = pad_sequences(tokenizer.texts_to_sequences(df['message']), maxlen=100)
y = df['label'].values

split = int(len(df) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

model = Sequential([
    Embedding(5000, 64, input_length=100),
    Bidirectional(LSTM(64, dropout=0.2)),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.2)

loss, acc = model.evaluate(X_test, y_test)
print(f"\n✅ Accuracy: {acc:.4f}")
# Out:
# Total messages: 5572
# Spam: 747 | Ham: 4825
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 11s 26ms/step - accuracy: 0.9234 - loss: 0.2277 - val_accuracy: 0.9809 - val_loss: 0.0638
# Epoch 2/5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9891 - loss: 0.0406 - val_accuracy: 0.9888 - val_loss: 0.0489
# Epoch 3/5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9964 - loss: 0.0194 - val_accuracy: 0.9854 - val_loss: 0.0533
# Epoch 4/5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9969 - loss: 0.0105 - val_accuracy: 0.9854 - val_loss: 0.0609
# Epoch 5/5
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9989 - loss: 0.0066 - val_accuracy: 0.9843 - val_loss: 0.0643
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9857 - loss: 0.0576
#
# ✅ Accuracy: 0.9857

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

print("="*50)
print("LOADING SPAM DATASET")
print("="*50)

df = pd.read_csv("spam.csv", encoding='latin-1')
df = df[['v1', 'v2']]
df.columns = ['label', 'message']
df['label'] = df['label'].map({'ham': 0, 'spam': 1})

print(f"Total messages: {len(df)}")
print(f"Spam: {df['label'].sum()} | Ham: {len(df)-df['label'].sum()}")

print("\n" + "="*50)
print("PREPROCESSING TEXT")
print("="*50)

tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(df['message'])
X = pad_sequences(tokenizer.texts_to_sequences(df['message']), maxlen=100)
y = df['label'].values

split = int(len(df) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

print(f"Training samples: {len(X_train)}")
print(f"Testing samples: {len(X_test)}")

print("\n" + "="*50)
print("BUILDING LSTM NEURAL NETWORK")
print("="*50)

model = Sequential([
    Embedding(5000, 64, input_length=100),
    Bidirectional(LSTM(64, dropout=0.2)),
    Dense(32, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

print("\n" + "="*50)
print("TRAINING MODEL")
print("="*50)

history = model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.2)

print("\n" + "="*50)
print("EVALUATING MODEL")
print("="*50)

loss, accuracy = model.evaluate(X_test, y_test)
print(f"\n✅ SPAM DETECTION ACCURACY: {accuracy:.4f}")

print("\n" + "="*50)
print("TESTING WITH CUSTOM MESSAGES")
print("="*50)

test_messages = [
    "Congratulations! You won $1000! Click here to claim",
    "Hey, want to grab lunch tomorrow?",
    "URGENT! Your account will be closed. Verify now!",
    "I'll be home by 6pm"
]

for msg in test_messages:
    seq = tokenizer.texts_to_sequences([msg])
    pad = pad_sequences(seq, maxlen=100)
    pred = model.predict(pad, verbose=0)[0][0]
    result = "SPAM" if pred > 0.5 else "HAM"
    print(f"\nMessage: {msg}")
    print(f"Result: {result} (confidence: {pred:.2%})")

print("\n🎉 SPAM DETECTION COMPLETE!")
# Out:
# ...
# LOADING SPAM DATASET
# ...
# Total messages: 5572
# Spam: 747 | Ham: 4825
#
# ...
# PREPROCESSING TEXT
# ...
# Training samples: 4457
# Testing samples: 1115
#
# ...
# BUILDING LSTM NEURAL NETWORK
# ...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_2 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ ?                      │   0 (unbuilt) │
# ...

# %%
from google.colab import files
print("Upload IMDB_Dataset.csv:")
uploaded = files.upload()
# Out:
# Upload IMDB_Dataset.csv:
#      <input type="file" id="files-795b3805-fbd4-4830-a3c6-086993995649" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-795b3805-fbd4-4830-a3c6-086993995649">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

print("="*50)
print("LOADING IMDB DATASET")
print("="*50)

df = pd.read_csv("IMDB_Dataset.csv")
df['label'] = df['sentiment'].map({'positive': 1, 'negative': 0})

print(f"Total reviews: {len(df)}")
print(f"Positive: {df['label'].sum()} | Negative: {len(df)-df['label'].sum()}")

# Use 10,000 samples for faster training
df_sample = df.sample(10000, random_state=42)
print(f"Using sample: {len(df_sample)} reviews")

print("\n" + "="*50)
print("PREPROCESSING TEXT")
print("="*50)

tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(df_sample['review'])
X = pad_sequences(tokenizer.texts_to_sequences(df_sample['review']), maxlen=200)
y = df_sample['label'].values

split = int(len(df_sample) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

print(f"Training samples: {len(X_train)}")
print(f"Testing samples: {len(X_test)}")

print("\n" + "="*50)
print("BUILDING BiLSTM NEURAL NETWORK")
print("="*50)

model = Sequential([
    Embedding(10000, 128, input_length=200),
    Bidirectional(LSTM(64, dropout=0.2)),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()

print("\n" + "="*50)
print("TRAINING MODEL (This may take 5-10 minutes)")
print("="*50)

history = model.fit(X_train, y_train, epochs=3, batch_size=64, validation_split=0.2)

print("\n" + "="*50)
print("EVALUATING MODEL")
print("="*50)

loss, accuracy = model.evaluate(X_test, y_test)
print(f"\n✅ SENTIMENT ANALYSIS ACCURACY: {accuracy:.4f}")

print("\n" + "="*50)
print("TESTING WITH CUSTOM REVIEWS")
print("="*50)

test_reviews = [
    "This movie was amazing! Best film ever!",
    "Worst movie ever. Complete waste of time.",
    "The acting was superb, I loved it!",
    "Terrible plot, boring characters."
]

for review in test_reviews:
    seq = tokenizer.texts_to_sequences([review])
    pad = pad_sequences(seq, maxlen=200)
    pred = model.predict(pad, verbose=0)[0][0]
    result = "POSITIVE" if pred > 0.5 else "NEGATIVE"
    print(f"\nReview: {review}")
    print(f"Sentiment: {result} (confidence: {pred:.2%})")

print("\n🎉 SENTIMENT ANALYSIS COMPLETE!")
# Out:
# ...
# LOADING IMDB DATASET
# ...
# Total reviews: 50000
# Positive: 25000 | Negative: 25000
# Using sample: 10000 reviews
#
# ...
# PREPROCESSING TEXT
# ...
# Training samples: 8000
# Testing samples: 2000
#
# ...
# BUILDING BiLSTM NEURAL NETWORK
# ...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
import pickle
from google.colab import files

# Spam model save
model.save("spam_lstm_model.h5")
with open("spam_tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

files.download("spam_lstm_model.h5")
files.download("spam_tokenizer.pkl")

# Sentiment model save
model.save("sentiment_bilstm_model.h5")
with open("sentiment_tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

files.download("sentiment_bilstm_model.h5")
files.download("sentiment_tokenizer.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
